# %%
# !pip install pandas==2.0.3 matplotlib==3.7.2 lazypredict scikit-learn==1.3.0 seaborn scikit-learn-intelex dpctl ipython==8.15.0 ipykernel==6.25.0 numpy==1.24.3 jupyter==1.0.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas==2.0.3 in /home/benyamain/.local/lib/python3.10/site-packages (2.0.3)
# Requirement already satisfied: matplotlib==3.7.2 in /home/benyamain/.local/lib/python3.10/site-packages (3.7.2)
# Requirement already satisfied: lazypredict in /home/benyamain/.local/lib/python3.10/site-packages (0.2.12)
# Requirement already satisfied: scikit-learn==1.3.0 in /home/benyamain/.local/lib/python3.10/site-packages (1.3.0)
# Requirement already satisfied: seaborn in /home/benyamain/.local/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: scikit-learn-intelex in /home/benyamain/.local/lib/python3.10/site-packages (2024.3.0)
# Requirement already satisfied: dpctl in /home/benyamain/.local/lib/python3.10/site-packages (0.16.0)
# Requirement already satisfied: ipython==8.15.0 in /home/benyamain/.local/lib/python3.10/site-packages (8.15.0)
# Requirement already satisfied: ipykernel==6.25.0 in /home/benyamain/.local/lib/python3.10/site-packages (6.25.0)
# Requirement already satisfied: numpy==1.24.3 in /home/benyamain/.local/lib/python3.10/site-packages (1.24.3)
# Requirement already satisfied: jupyter==1.0.0 in /home/benyamain/.local/lib/python3.10/site-packages (1.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/benyamain/.local/lib/python3.10/site-packages (from pandas==2.0.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas==2.0.3) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/benyamain/.local/lib/python3.10/site-packages (from pandas==2.0.3) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/benyamain/.local/lib/python3.10/site-packages (from matplotlib==3.7.2) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/lib/python3/dist-packages (from matplotlib==3.7.2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/lib/python3/dist-packages (from matplotlib==3.7.2) (4.29.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/lib/python3/dist-packages (from matplotlib==3.7.2) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from matplotlib==3.7.2) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib==3.7.2) (9.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib==3.7.2) (2.4.7)
# Requirement already satisfied: scipy>=1.5.0 in /usr/lib/python3/dist-packages (from scikit-learn==1.3.0) (1.8.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/benyamain/.local/lib/python3.10/site-packages (from scikit-learn==1.3.0) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/benyamain/.local/lib/python3.10/site-packages (from scikit-learn==1.3.0) (3.5.0)
# Requirement already satisfied: backcall in /usr/lib/python3/dist-packages (from ipython==8.15.0) (0.2.0)
# Requirement already satisfied: decorator in /usr/lib/python3/dist-packages (from ipython==8.15.0) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in /usr/lib/python3/dist-packages (from ipython==8.15.0) (0.18.0)
# Requirement already satisfied: matplotlib-inline in /usr/lib/python3/dist-packages (from ipython==8.15.0) (0.1.3)
# Requirement already satisfied: pickleshare in /usr/lib/python3/dist-packages (from ipython==8.15.0) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/benyamain/.local/lib/python3.10/site-packages (from ipython==8.15.0) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from ipython==8.15.0) (2.17.2)
# Requirement already satisfied: stack-data in /home/benyamain/.local/lib/python3.10/site-packages (from ipython==8.15.0) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /home/benyamain/.local/lib/python3.10/site-packages (from ipython==8.15.0) (5.14.3)
# Requirement already satisfied: exceptiongroup in /home/benyamain/.local/lib/python3.10/site-packages (from ipython==8.15.0) (1.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython==8.15.0) (4.8.0)
# Requirement already satisfied: comm>=0.1.1 in /home/benyamain/.local/lib/python3.10/site-packages (from ipykernel==6.25.0) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/benyamain/.local/lib/python3.10/site-packages (from ipykernel==6.25.0) (1.8.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/lib/python3/dist-packages (from ipykernel==6.25.0) (7.1.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/benyamain/.local/lib/python3.10/site-packages (from ipykernel==6.25.0) (5.7.2)
# Requirement already satisfied: nest-asyncio in /usr/lib/python3/dist-packages (from ipykernel==6.25.0) (1.5.4)
# Requirement already satisfied: psutil in /usr/lib/python3/dist-packages (from ipykernel==6.25.0) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in /usr/lib/python3/dist-packages (from ipykernel==6.25.0) (22.3.0)
# Requirement already satisfied: tornado>=6.1 in /usr/lib/python3/dist-packages (from ipykernel==6.25.0) (6.1)
# Requirement already satisfied: notebook in /usr/lib/python3/dist-packages (from jupyter==1.0.0) (6.4.8)
# Requirement already satisfied: qtconsole in /home/benyamain/.local/lib/python3.10/site-packages (from jupyter==1.0.0) (5.5.1)
# Requirement already satisfied: jupyter-console in /home/benyamain/.local/lib/python3.10/site-packages (from jupyter==1.0.0) (6.6.3)
# Requirement already satisfied: nbconvert in /usr/lib/python3/dist-packages (from jupyter==1.0.0) (6.4.0)
# Requirement already satisfied: ipywidgets in /usr/lib/python3/dist-packages (from jupyter==1.0.0) (6.0.0)
# Requirement already satisfied: click in /home/benyamain/.local/lib/python3.10/site-packages (from lazypredict) (8.1.7)
# Requirement already satisfied: tqdm in /home/benyamain/.local/lib/python3.10/site-packages (from lazypredict) (4.66.2)
# Requirement already satisfied: lightgbm in /home/benyamain/.local/lib/python3.10/site-packages (from lazypredict) (4.3.0)
# Requirement already satisfied: xgboost in /home/benyamain/.local/lib/python3.10/site-packages (from lazypredict) (2.0.3)
# Requirement already satisfied: daal4py==2024.3.0 in /home/benyamain/.local/lib/python3.10/site-packages (from scikit-learn-intelex) (2024.3.0)
# Requirement already satisfied: daal==2024.3.0 in /home/benyamain/.local/lib/python3.10/site-packages (from daal4py==2024.3.0->scikit-learn-intelex) (2024.3.0)
# Requirement already satisfied: tbb==2021.* in /home/benyamain/.local/lib/python3.10/site-packages (from daal==2024.3.0->daal4py==2024.3.0->scikit-learn-intelex) (2021.12.0)
# Requirement already satisfied: dpcpp-cpp-rt in /home/benyamain/.local/lib/python3.10/site-packages (from dpctl) (2024.1.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/lib/python3/dist-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel==6.25.0) (2.5.1)
# Requirement already satisfied: wcwidth in /usr/lib/python3/dist-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython==8.15.0) (0.2.5)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas==2.0.3) (1.16.0)
# Requirement already satisfied: intel-opencl-rt==2024.1.0 in /home/benyamain/.local/lib/python3.10/site-packages (from dpcpp-cpp-rt->dpctl) (2024.1.0)
# Requirement already satisfied: intel-openmp==2024.1.0 in /home/benyamain/.local/lib/python3.10/site-packages (from dpcpp-cpp-rt->dpctl) (2024.1.0)
# Requirement already satisfied: intel-cmplr-lib-rt==2024.1.0 in /home/benyamain/.local/lib/python3.10/site-packages (from dpcpp-cpp-rt->dpctl) (2024.1.0)
# Requirement already satisfied: intel-cmplr-lic-rt==2024.1.0 in /home/benyamain/.local/lib/python3.10/site-packages (from dpcpp-cpp-rt->dpctl) (2024.1.0)
# Requirement already satisfied: qtpy>=2.4.0 in /home/benyamain/.local/lib/python3.10/site-packages (from qtconsole->jupyter==1.0.0) (2.4.1)
# Requirement already satisfied: executing>=1.2.0 in /home/benyamain/.local/lib/python3.10/site-packages (from stack-data->ipython==8.15.0) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/benyamain/.local/lib/python3.10/site-packages (from stack-data->ipython==8.15.0) (2.4.1)
# Requirement already satisfied: pure-eval in /home/benyamain/.local/lib/python3.10/site-packages (from stack-data->ipython==8.15.0) (0.2.2)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dataset
data = pd.read_csv("/home/benyamain/Desktop/lulc-air-quality/dataset/california-eleven-month-mol-m2.csv")

# %%
# Just to understand the dist. more
bins = pd.qcut(data['NO2_column_number_density'], q=2)
print(bins.value_counts(sort=False))

# Hist.
plt.hist(data['NO2_column_number_density'], bins=2)

plt.xlabel('NO2_column_number_density')
plt.ylabel('Frequency')
plt.title('Histogram of NO2_column_number_density')

plt.savefig('/home/benyamain/Desktop/lulc-air-quality/figures/discretization-equal-frequency.png')
plt.show()
# Out:
# NO2_column_number_density
# (-0.0009216000000000001, 0.000167]    524288
# (0.000167, 0.000408]                  524287
# Name: count, dtype: int64

# %%
# Discretize the attributes using equal width method
# The big caveat is that the density levels are low and high RESPECTIVE to the dist. of the dataset
data['NO2_column_number_density'] = pd.qcut(x=data['NO2_column_number_density'], labels=["Low NO2 Levels", "High NO2 Levels"], q=2)
print(data['NO2_column_number_density'].head(100))
# Out:
# 0     High NO2 Levels
# 1     High NO2 Levels
# 2     High NO2 Levels
# 3     High NO2 Levels
# 4     High NO2 Levels
#            ...
# 95    High NO2 Levels
# 96    High NO2 Levels
# 97    High NO2 Levels
# 98    High NO2 Levels
# 99    High NO2 Levels
# Name: NO2_column_number_density, Length: 100, dtype: category
# Categories (2, object): ['Low NO2 Levels' < 'High NO2 Levels']

# %%
import seaborn as sns

sample = data.sample(n=50) 

sample.set_index('NO2_column_number_density', inplace=True)

# Create a heatmap
plt.figure(figsize=(20, 20))
sns.heatmap(sample, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Relationship between LULC and NO2 Levels')
plt.savefig('/home/benyamain/Desktop/lulc-air-quality/figures/heatmap.png')
plt.show()

# %%
# Drop the target output from the input train set
X = data[data.columns.drop('NO2_column_number_density')]
print("Input Attributes: ", X)
# Set the target output to the output train set
y = data['NO2_column_number_density']
print("Training Labels: ", y)
# Out:
# Input Attributes:           bare  built  crops  flooded_vegetation  grass  shrub_and_scrub  \
# 0        0.12   0.62   0.04                0.03   0.02             0.05
# 1        0.07   0.66   0.04                0.04   0.03             0.04
# 2        0.11   0.62   0.03                0.03   0.03             0.04
# 3        0.18   0.53   0.04                0.03   0.02             0.05
# 4        0.20   0.48   0.04                0.04   0.02             0.05
# ...       ...    ...    ...                 ...    ...              ...
# 1048570  0.08   0.03   0.07                0.03   0.05             0.28
# 1048571  0.05   0.03   0.04                0.03   0.05             0.16
# 1048572  0.05   0.04   0.06                0.03   0.06             0.23
# 1048573  0.06   0.04   0.09                0.02   0.06             0.37
# 1048574  0.06   0.04   0.10                0.02   0.06             0.35
#
#          snow_and_ice  trees  water
# 0                0.03   0.03   0.05
# 1                0.03   0.04   0.05
# 2                0.02   0.03   0.07
# 3                0.03   0.03   0.09
# 4                0.03   0.03   0.10
# ...               ...    ...    ...
# 1048570          0.03   0.36   0.05
# 1048571          0.03   0.56   0.04
# 1048572          0.03   0.45   0.04
# 1048573          0.04   0.26   0.04
# 1048574          0.04   0.27   0.04
#
# [1048575 rows x 9 columns]
# Training Labels:  0          High NO2 Levels
# 1          High NO2 Levels
# 2          High NO2 Levels
# 3          High NO2 Levels
# 4          High NO2 Levels
#                 ...
# 1048570     Low NO2 Levels
# 1048571     Low NO2 Levels
# 1048572     Low NO2 Levels
# 1048573     Low NO2 Levels
# 1048574     Low NO2 Levels
# Name: NO2_column_number_density, Length: 1048575, dtype: category
# Categories (2, object): ['Low NO2 Levels' < 'High NO2 Levels']

# %%
# Imports
from sklearnex import patch_sklearn, config_context
patch_sklearn()

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# Based on the dist. of the histogram
class_weights_custom = {"Low NO2 Levels": 0.20, "High NO2 Levels": 0.75}

# DTC
with config_context(target_offload="gpu:0"):
    dtc = DecisionTreeClassifier(criterion='gini', splitter='best', max_depth=10, min_samples_split=10, min_samples_leaf=5, max_features=None, class_weight=None)

    # Train the model
    dtc.fit(X_train, y_train)

    # Predictions on the test set
    y_pred = dtc.predict(X_test)

    cross_val_scores = cross_val_score(dtc, X_train, y_train, cv=10, scoring='accuracy')

    # Eval
    accuracy = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred)
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
print("Accuracy: ", accuracy)
print(report)

# Cross validation
print(f'CV Scores: {cross_val_scores}')
print(f'Mean CV Accuracy: {cross_val_scores.mean()}')
# Out:
# Accuracy:  0.8458813151181365
#                  precision    recall  f1-score   support
#
# High NO2 Levels       0.86      0.82      0.84    104320
#  Low NO2 Levels       0.83      0.87      0.85    105395
#
#        accuracy                           0.85    209715
#       macro avg       0.85      0.85      0.85    209715
#    weighted avg       0.85      0.85      0.85    209715
#
# CV Scores: [0.8462914  0.84505162 0.84618411 0.84444365 0.84478936 0.8464106
#  0.84571919 0.84397873 0.84658942 0.84679207]
# Mean CV Accuracy: 0.8456250149011755

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Understanding the relationship between air quality attr. related to the LULC class labels
sns.pairplot(data, x_vars=['bare', 'built', 'crops', 'flooded_vegetation', 'grass', 'shrub_and_scrub', 'snow_and_ice', 'trees', 'water'], y_vars='NO2_column_number_density', kind='scatter')
plt.savefig('/home/benyamain/Desktop/lulc-air-quality/figures/scatterplot-individual.png')
plt.show()

# %%
# Drop the target output from the input train set
X = data[data.columns.drop('NO2_column_number_density')]
print("Input Attributes: ", X)
# Set the target output to the output train set
y = data['NO2_column_number_density']
print("Training Labels: ", y)
# Out:
# Input Attributes:           bare  built  crops  flooded_vegetation  grass  shrub_and_scrub  \
# 0        0.12   0.62   0.04                0.03   0.02             0.05
# 1        0.07   0.66   0.04                0.04   0.03             0.04
# 2        0.11   0.62   0.03                0.03   0.03             0.04
# 3        0.18   0.53   0.04                0.03   0.02             0.05
# 4        0.20   0.48   0.04                0.04   0.02             0.05
# ...       ...    ...    ...                 ...    ...              ...
# 1048570  0.08   0.03   0.07                0.03   0.05             0.28
# 1048571  0.05   0.03   0.04                0.03   0.05             0.16
# 1048572  0.05   0.04   0.06                0.03   0.06             0.23
# 1048573  0.06   0.04   0.09                0.02   0.06             0.37
# 1048574  0.06   0.04   0.10                0.02   0.06             0.35
#
#          snow_and_ice  trees  water
# 0                0.03   0.03   0.05
# 1                0.03   0.04   0.05
# 2                0.02   0.03   0.07
# 3                0.03   0.03   0.09
# 4                0.03   0.03   0.10
# ...               ...    ...    ...
# 1048570          0.03   0.36   0.05
# 1048571          0.03   0.56   0.04
# 1048572          0.03   0.45   0.04
# 1048573          0.04   0.26   0.04
# 1048574          0.04   0.27   0.04
#
# [1048575 rows x 9 columns]
# Training Labels:  0          High NO2 Levels
# 1          High NO2 Levels
# 2          High NO2 Levels
# 3          High NO2 Levels
# 4          High NO2 Levels
#                 ...
# 1048570     Low NO2 Levels
# 1048571     Low NO2 Levels
# 1048572     Low NO2 Levels
# 1048573     Low NO2 Levels
# 1048574     Low NO2 Levels
# Name: NO2_column_number_density, Length: 1048575, dtype: category
# Categories (2, object): ['Low NO2 Levels' < 'High NO2 Levels']

# %%
# Imports
from sklearnex import patch_sklearn, config_context
patch_sklearn()

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, classification_report

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# Based on the dist. of the histogram
class_weights_custom = {"Low NO2 Levels": 0.20, "High NO2 Levels": 0.75}

# Random Forest Classifier
with config_context(target_offload="gpu:0"):
    rf_clf = RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='sqrt', max_leaf_nodes=None, min_impurity_decrease=0.0, bootstrap=True, oob_score=False, n_jobs=None, random_state=None, verbose=0, warm_start=False, class_weight=None, ccp_alpha=0.0, max_samples=None)

    # Train the model
    rf_clf.fit(X_train, y_train)

    # Make predictiotns for class labels
    y_pred = rf_clf.predict(X_test)

    cross_val_scores = cross_val_score(rf_clf, X_train, y_train, cv=10, scoring='accuracy')

    # Eval
    accuracy = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred)
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience
# WARNING:root:Device support is limited. Please install dpctl for full experience

# %%
print("Accuracy: ", accuracy)
print(report)

# Cross validation
print(f'CV Scores: {cross_val_scores}')
print(f'Mean CV Accuracy: {cross_val_scores.mean()}')
# Out:
# Accuracy:  0.8562382280714302
#                  precision    recall  f1-score   support
#
# High NO2 Levels       0.87      0.84      0.85    104320
#  Low NO2 Levels       0.85      0.87      0.86    105395
#
#        accuracy                           0.86    209715
#       macro avg       0.86      0.86      0.86    209715
#    weighted avg       0.86      0.86      0.86    209715
#
# CV Scores: [0.85473142 0.8547791  0.85637651 0.85386119 0.85630499 0.85584007
#  0.85635267 0.85482679 0.85667453 0.8569368 ]
# Mean CV Accuracy: 0.855668407123954

# %%
# Determining what attr. hold % of class labels
feature_importance = pd.Series(rf_clf.feature_importances_, index=X.columns).sort_values(ascending=False)
print(feature_importance)
# Out:
# built                0.25
# shrub_and_scrub      0.17
# trees                0.14
# grass                0.10
# crops                0.08
# water                0.07
# bare                 0.07
# snow_and_ice         0.06
# flooded_vegetation   0.06
# dtype: float64

# %%
from sklearnex import patch_sklearn, config_context
patch_sklearn()

from lazypredict.Supervised import LazyClassifier
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

with config_context(target_offload="gpu:0"):
    clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
    models, predictions = clf.fit(X_train, X_test, y_train, y_test)

    print(models)
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 4
#       1 from sklearnex import patch_sklearn, config_context
#       2 patch_sklearn()
# ----> 4 from lazypredict.Supervised import LazyClassifier
#       5 from sklearn.model_selection import train_test_split
#       7 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
#
# File ~/.local/lib/python3.10/site-packages/lazypredict/Supervised.py:98
#      89 # CLASSIFIERS.append(('CatBoostClassifier',catboost.CatBoostClassifier))
#      91 numeric_transformer = Pipeline(
#      92     steps=[("imputer", SimpleImputer(strategy="mean")), ("scaler", StandardScaler())]
#      93 )
#      95 categorical_transformer_low = Pipeline(
#      96     steps=[
#      97         ("imputer", SimpleImputer(strategy="constant", fill_value="missing")),
# ---> 98         ("encoding", OneHotEncoder(handle_unknown="ignore", sparse=False)),
#      99     ]
#     100 )
#     102 categorical_transformer_high = Pipeline(
#     103     steps=[
#     104         ("imputer", SimpleImputer(strategy="constant", fill_value="missing")),
#    (...)
#     107     ]
#     108 )
#     111 # Helper function
#
# TypeError: OneHotEncoder.__init__() got an unexpected keyword argument 'sparse'
